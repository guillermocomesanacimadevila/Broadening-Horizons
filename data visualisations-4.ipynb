# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

# %%
def read_file(location):
    with open(os.path.expanduser(location), "r") as file:
        return pd.read_csv(file, sep=",")

# %%
df = read_file("/Users/guillermocomesanacimadevila/Desktop/BH_analysis/dacid/co2-emissions-and-gdp.csv")

# %%
df
# Out:
#             Entity Code  Year  GDP, PPP (constant 2017 international $)  \
# 0      Afghanistan  AFG  2002                              2.689005e+10
# 1      Afghanistan  AFG  2003                              2.926506e+10
# 2      Afghanistan  AFG  2004                              2.967890e+10
# 3      Afghanistan  AFG  2005                              3.301176e+10
# 4      Afghanistan  AFG  2006                              3.478033e+10
# ...            ...  ...   ...                                       ...
# 29510     Zimbabwe  ZWE  1986                                       NaN
# 29511     Zimbabwe  ZWE  1987                                       NaN
# 29512     Zimbabwe  ZWE  1988                                       NaN
# 29513     Zimbabwe  ZWE  1989                                       NaN
# 29514     Zimbabwe  ZWE  2023                                       NaN
#
#        Annual CO₂ emissions  Annual consumption-based CO₂ emissions
# ...

# %%
df2 = df[((df["Entity"] == "European Union (27)") | (df["Entity"] == "United States")) & (df["Year"].between(2010, 2020))]

# %%
df2
# Out:
#                     Entity Code  Year  \
# 9537   European Union (27)  NaN  2010
# 9538   European Union (27)  NaN  2011
# 9539   European Union (27)  NaN  2012
# 9540   European Union (27)  NaN  2013
# 9541   European Union (27)  NaN  2014
# 9542   European Union (27)  NaN  2015
# 9543   European Union (27)  NaN  2016
# 9544   European Union (27)  NaN  2017
# 9545   European Union (27)  NaN  2018
# 9546   European Union (27)  NaN  2019
# 9547   European Union (27)  NaN  2020
# 27872        United States  USA  2010
# 27873        United States  USA  2011
# 27874        United States  USA  2012
# 27875        United States  USA  2013
# 27876        United States  USA  2014
# 27877        United States  USA  2015
# 27878        United States  USA  2016
# 27879        United States  USA  2017
# 27880        United States  USA  2018
# 27881        United States  USA  2019
# 27882        United States  USA  2020
#
#        GDP, PPP (constant 2017 international $)  Annual CO₂ emissions  \
# ...

# %%
df2.shape
# Out:
# (22, 6)

# %%
df_eu = df2[df2["Entity"] == "European Union (27)"]
df_usa = df2[df2["Entity"] == "United States"]

# %%
df_eu.shape, df_usa.shape # ensure shape = "equal"
# Out:
# ((11, 6), (11, 6))

# %%
df_eu
# Out:
#                    Entity Code  Year  \
# 9537  European Union (27)  NaN  2010
# 9538  European Union (27)  NaN  2011
# 9539  European Union (27)  NaN  2012
# 9540  European Union (27)  NaN  2013
# 9541  European Union (27)  NaN  2014
# 9542  European Union (27)  NaN  2015
# 9543  European Union (27)  NaN  2016
# 9544  European Union (27)  NaN  2017
# 9545  European Union (27)  NaN  2018
# 9546  European Union (27)  NaN  2019
# 9547  European Union (27)  NaN  2020
#
#       GDP, PPP (constant 2017 international $)  Annual CO₂ emissions  \
# 9537                              1.721647e+13          3.424056e+09
# 9538                              1.754065e+13          3.326834e+09
# 9539                              1.741743e+13          3.257576e+09
# 9540                              1.739948e+13          3.175110e+09
# 9541                              1.769231e+13          3.038410e+09
# 9542                              1.811547e+13          3.094754e+09
# ...

# %%
plt.figure(figsize=(10, 6))

plt.plot(df_eu["Year"], df_eu["GDP, PPP (constant 2017 international $)"], 
         label="EU GDP", marker="o", linestyle="-", linewidth=2, color="#228B22")

plt.plot(df_usa["Year"], df_usa["GDP, PPP (constant 2017 international $)"], 
         label="USA GDP", marker="s", linestyle="--", linewidth=2, color="#317873")

plt.xlabel("Year", fontsize=14, labelpad=10, fontweight="bold")
plt.ylabel("GDP (PPP, constant 2017 international $)", fontsize=14, labelpad=10, fontweight="bold")
plt.title("GDP Comparison: EU vs USA (2010 - 2020)", fontsize=18, pad=15, fontweight="bold")
plt.xticks(df_eu["Year"], fontsize=12)
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{x/1e13:.1f}T'))
plt.grid(visible=True, linestyle="--", alpha=0.6)
plt.legend(fontsize=12, loc="upper left", frameon=True, shadow=True, fancybox=True, borderpad=1)

plt.tight_layout()
plt.savefig("EU_vs_USA_GDP_Clean.png", dpi=300, bbox_inches="tight", transparent=True)

plt.show()

# %%
df2.columns
# Out:
# Index(['Entity', 'Code', 'Year', 'GDP, PPP (constant 2017 international $)',
#        'Annual CO₂ emissions', 'Annual consumption-based CO₂ emissions'],
#       dtype='object')

# %%
df2
# Out:
#                     Entity Code  Year  \
# 9537   European Union (27)  NaN  2010
# 9538   European Union (27)  NaN  2011
# 9539   European Union (27)  NaN  2012
# 9540   European Union (27)  NaN  2013
# 9541   European Union (27)  NaN  2014
# 9542   European Union (27)  NaN  2015
# 9543   European Union (27)  NaN  2016
# 9544   European Union (27)  NaN  2017
# 9545   European Union (27)  NaN  2018
# 9546   European Union (27)  NaN  2019
# 9547   European Union (27)  NaN  2020
# 27872        United States  USA  2010
# 27873        United States  USA  2011
# 27874        United States  USA  2012
# 27875        United States  USA  2013
# 27876        United States  USA  2014
# 27877        United States  USA  2015
# 27878        United States  USA  2016
# 27879        United States  USA  2017
# 27880        United States  USA  2018
# 27881        United States  USA  2019
# 27882        United States  USA  2020
#
#        GDP, PPP (constant 2017 international $)  Annual CO₂ emissions  \
# ...

# %%
plt.figure(figsize=(10, 6))

plt.plot(df_eu["Year"], df_eu["Annual CO₂ emissions"], 
         label="EU CO₂ emissions", marker="o", linestyle="-", linewidth=2, color="#228B22")

plt.plot(df_usa["Year"], df_usa["Annual CO₂ emissions"], 
         label="USA CO₂ emissions", marker="s", linestyle="--", linewidth=2, color="#317873")

plt.xlabel("Year", fontsize=14, labelpad=10, fontweight="bold")
plt.ylabel("Annual CO₂ emissions", fontsize=14, labelpad=10, fontweight="bold")
plt.title("Annual CO₂ emissions", fontsize=18, pad=15, fontweight="bold")
plt.xticks(df_eu["Year"], fontsize=12)
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{x:,.0f}'))
plt.grid(visible=True, linestyle="--", alpha=0.6)
plt.legend(fontsize=12, loc="upper left", bbox_to_anchor=(1, 1), frameon=True, shadow=True, fancybox=True, borderpad=1)

plt.tight_layout()

plt.savefig("EU_vs_USA_CO2_fixed.png", dpi=300, bbox_inches="tight")
plt.show()
